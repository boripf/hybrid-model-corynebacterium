# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from B_model_sim import model, plot_simulation
# Out:
# 2767
# /Users/marcl./Documents/ALL /Studium /Master/4. Semester_Thesis/hybrid-model-corynebacterium/B_model_sim.py:154: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Load parameters from YAML file
with open('config/parameters.yml', 'r') as file:
    param = yaml.safe_load(file)

# %%
time, biomass, substrate, volume, dS_dt , dCO2_dt = model(param)
plot_simulation(time, biomass, substrate, dS_dt,  dCO2_dt, 'Fedbatch + Monod Logistic mu(0.2) + Yxs qs')
# Out:
# 2767
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 time, biomass, substrate, volume, dS_dt , dCO2_dt = model(param)
#       2 plot_simulation(time, biomass, substrate, dS_dt,  dCO2_dt, 'Fedbatch + Monod Logistic mu(0.2) + Yxs qs')
#
# ValueError: not enough values to unpack (expected 6, got 5)
