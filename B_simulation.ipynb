# %% [markdown]
# #### Simple Mechanistic Model

# %% [markdown]
# ---

# %% [markdown]
# #### Code

# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from B_model import model, plot_simulation

# %%
delta_t = 2
time, biomass, substrate = model(delta_t)
plot_simulation(time, biomass, substrate, 'Fedbatch')
# Out:
# c:\Users\dxp2904\Downloads\Project_June_Ferm\hybrid-model-corynebacterium\B_model.py:142: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
