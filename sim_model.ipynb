# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from def_model import *

# %%
# Load parameters from YAML file
with open('parameters.yml', 'r') as file:
    param = yaml.safe_load(file)

# %%
# Simulation settings
t0 = 0
t_end = 40
dt = 0.1

# %%
time, biomass, substrate = model_basic(param, t0, t_end, dt)

# %%
df_exp = pd.read_csv('fermentation raw data/data_combined.csv')
df_exp.shape
# Out:
# (2625, 19)

# %%
# Plot the results
plt.plot(time, biomass, label='Biomass')
plt.plot(time, substrate, label='Substrate')
plt.scatter(df_exp['time [h]'], df_exp['Biomass [g/L]'], label='Biomass exp', color='violet')
plt.xlabel('Time [h]')
plt.ylabel('Concentration [g/L]')
plt.legend()
plt.show()
