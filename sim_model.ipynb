# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from def_model import *

# %%
# Load parameters from YAML file
with open('parameters.yml', 'r') as file:
    param = yaml.safe_load(file)

# %%
# Simulation settings
t0 = 0
t_end = 46
dt = 1/60

# %%
time, biomass, substrate = model_basic_logistic_mu(param, t0, t_end, dt)
plot_simulation(time, biomass, substrate, 'Logistic mu')

# %%
time, biomass, substrate = model_monod_logistic_mu(param, t0, t_end, dt)
plot_simulation(time, biomass, substrate, 'Logistic + Monod mu')

# %%
# the smaller the Ki value (7.51 compared to 751), the flatter the curve around 10h
Ki=7.51
time, biomass, substrate = model_monod_inhib_logistic_mu(param, t0, t_end, dt, Ki)
plot_simulation(time, biomass, substrate, f'Logistic + Gluc Inhib + Monod mu - Ki={Ki}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # the smaller the Ki value (7.51 compared to 751), the flatter the curve around 10h
#       2 Ki=7.51
# ----> 3 time, biomass, substrate = model_monod_inhib_logistic_mu(param, t0, t_end, dt, Ki)
#       4 plot_simulation(time, biomass, substrate, f'Logistic + Gluc Inhib + Monod mu - Ki={Ki}')
#
# TypeError: model_monod_inhib_logistic_mu() takes 4 positional arguments but 5 were given
