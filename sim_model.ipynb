# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from def_model import *

# %%
# Load parameters from YAML file
with open('parameters.yml', 'r') as file:
    param = yaml.safe_load(file)

# %%
# Simulation settings
t0 = 0
t_end = 46
dt = 1/60

# %%
time, biomass, substrate = model_basic_logistic_mu(param, t0, t_end, dt, 'Logistic mu')
plot_simulation(time, biomass, substrate)

# %%
time, biomass, substrate = model_monod_logistic_mu(param, t0, t_end, dt, 'Logistic mu')
plot_simulation(time, biomass, substrate)
