# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from B_model import model, plot_simulation

# %%
# Load parameters from YAML file
with open('config/parameters.yml', 'r') as file:
    param = yaml.safe_load(file)

# %%
time, biomass, substrate, volume, dS_dt = model(param)
plot_simulation(time, biomass, substrate, dS_dt, 'Fedbatch + Monod Logistic mu(0.2) + Monod + Inhib metab qs')
# Out:
# 2767
# c:\Users\Deborah\Documents\01_dtu\05_ProjectCourse\hybrid-model-corynebacterium\B_model.py:149: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
